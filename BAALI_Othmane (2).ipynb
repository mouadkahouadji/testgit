# %% [markdown]
# # Devoir
#
#
#
#
# ###  Module manipulation de données avec Pandas

# %% [markdown]
# Nous revenons à notre ensemble de données sur la piste cyclable ici. Je suis curieux de savoir si Montreal est une ville de velo banlieue ou une ville de cyclisme ludique - les gens font-ils plus de vélo les week-ends ou les jours de semaine?

# %% [markdown]
# ### Ajouter une colonne 'jour de la semaine' à notre dataframe

# %% [markdown]
# -1-
#
# Premièrement, nous devons charger les données, avec time index, ... Nous l'avons déjà fait auparavant (cf notebook précédent).
# Ensuite, nous allons simplement regarder la piste cyclable Berri.
#
# nb: utiliser les nombreux parametres de read_csv :
# - changer le séparateur de colonne par "," (parametre "sep")
# - Analyser les dates dans la colonne 'Date'
# - Dites-lui que nos dates ont le jour en premier au lieu du mois en premier
# - Définir l'index pour qu'elle soit la colonne 'Date'

# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("comptagevelo2017.csv",
              sep=",",
              index_col="Date",
              dayfirst=True,
              parse_dates=True,
              infer_datetime_format=True,
              keep_date_col=True)

# %%
a
# Out:
#            Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# Date
# 2017-01-01      00:00      38     35      NaN       20                NaN
# 2017-01-02      00:00     109     40      0.0       43                NaN
# 2017-01-03      00:00     141     24     24.0        9                NaN
# 2017-01-04      00:00     233     64     95.0        7                NaN
# 2017-01-05      00:00     265     93     94.0       11                NaN
# ...               ...     ...    ...      ...      ...                ...
# 2017-12-27      00:00     116     95     54.0        6                7.0
# 2017-12-28      00:00     137    112     51.0       21                3.0
# 2017-12-29      00:00     124     61     53.0       18                8.0
# 2017-12-30      00:00      80     69     44.0        3               10.0
# 2017-12-31      00:00      59     39     23.0        1                4.0
#
#             CSC (Côte Sainte-Catherine)  Eco-Totem - Métro Laurier  \
# Date
# 2017-01-01                           60                         58
# 2017-01-02                           61                         66
# 2017-01-03                           14                        131
# 2017-01-04                           12                        160
# 2017-01-05                           14                        160
# ...                                 ...                        ...
# 2017-12-27                           55                        112
# 2017-12-28                           32                        108
# 2017-12-29                           17                        229
# 2017-12-30                           23                         91
# 2017-12-31                           16                         59
#
#             Maisonneuve_2  Maisonneuve_3  Notre-Dame  Parc  PierDup  \
# Date
# 2017-01-01             38             12          10    13        9
# 2017-01-02            152             57           9    52       14
# 2017-01-03            216             74          32    71       17
# 2017-01-04            284             80          45    64        5
# 2017-01-05            306             97          38    97        6
# ...                   ...            ...         ...   ...      ...
# 2017-12-27            143             25           0    47        3
# 2017-12-28            123             36           0    31        4
# 2017-12-29            112             30           0    28        2
# 2017-12-30             57             23           0    21        3
# 2017-12-31             52             17           0    13        3
#
#             Pont Jacques-Cartier  Rachel / Hôtel de Ville  Rachel / Papineau  \
# Date
# 2017-01-01                   0.0                       42                 77
# 2017-01-02                   0.0                      136                231
# 2017-01-03                   0.0                       99                242
# 2017-01-04                  15.0                      128                296
# 2017-01-05                   0.0                      189                338
# ...                          ...                      ...                ...
# 2017-12-27                   1.0                       93                154
# 2017-12-28                   3.0                       72                138
# 2017-12-29                   8.0                       87                127
# 2017-12-30                   1.0                       92                122
# 2017-12-31                   7.0                       76                 80
#
#             René-Lévesque  Saint-Antoine  Saint-Laurent/Bellechasse  \
# Date
# 2017-01-01             15              8                         72
# 2017-01-02             22             10                        182
# 2017-01-03             53             28                        532
# 2017-01-04            131             33                        821
# 2017-01-05             89             45                        786
# ...                   ...            ...                        ...
# 2017-12-27             75             14                        143
# 2017-12-28             26             11                        123
# 2017-12-29             30              6                        130
# 2017-12-30             19              5                         85
# 2017-12-31             15              4                        102
#
#             Saint-Urbain
# Date
# 2017-01-01             5
# 2017-01-02             4
# 2017-01-03             5
# 2017-01-04             0
# 2017-01-05             9
# ...                  ...
# 2017-12-27             7
# 2017-12-28            21
# 2017-12-29            54
# 2017-12-30            13
# 2017-12-31             4
#
# [365 rows x 20 columns]

# %%
a.head()
# Out:
#            Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# Date
# 2017-01-01      00:00      38     35      NaN       20                NaN
# 2017-01-02      00:00     109     40      0.0       43                NaN
# 2017-01-03      00:00     141     24     24.0        9                NaN
# 2017-01-04      00:00     233     64     95.0        7                NaN
# 2017-01-05      00:00     265     93     94.0       11                NaN
#
#             CSC (Côte Sainte-Catherine)  Eco-Totem - Métro Laurier  \
# Date
# 2017-01-01                           60                         58
# 2017-01-02                           61                         66
# 2017-01-03                           14                        131
# 2017-01-04                           12                        160
# 2017-01-05                           14                        160
#
#             Maisonneuve_2  Maisonneuve_3  Notre-Dame  Parc  PierDup  \
# Date
# 2017-01-01             38             12          10    13        9
# 2017-01-02            152             57           9    52       14
# 2017-01-03            216             74          32    71       17
# 2017-01-04            284             80          45    64        5
# 2017-01-05            306             97          38    97        6
#
#             Pont Jacques-Cartier  Rachel / Hôtel de Ville  Rachel / Papineau  \
# Date
# 2017-01-01                   0.0                       42                 77
# 2017-01-02                   0.0                      136                231
# 2017-01-03                   0.0                       99                242
# 2017-01-04                  15.0                      128                296
# 2017-01-05                   0.0                      189                338
#
#             René-Lévesque  Saint-Antoine  Saint-Laurent/Bellechasse  \
# Date
# 2017-01-01             15              8                         72
# 2017-01-02             22             10                        182
# 2017-01-03             53             28                        532
# 2017-01-04            131             33                        821
# 2017-01-05             89             45                        786
#
#             Saint-Urbain
# Date
# 2017-01-01             5
# 2017-01-02             4
# 2017-01-03             5
# 2017-01-04             0
# 2017-01-05             9

# %% [markdown]
# Berri est une rue de Montréal avec une piste cyclable assez importante. Un ami l'utilise principalement pour se rendre à la bibliothèque, mais il l'utilisait parfois lorsque il travaillait dans le Vieux-Montréal.
#
# Nous allons donc créer un tableau de données (ici un Series) contenant uniquement les chemins cyclables du quartier de Berri.

# %%
d=a.Berri1.copy()

# %%
d
# Out:
# Date
# 2017-01-01     38
# 2017-01-02    109
# 2017-01-03    141
# 2017-01-04    233
# 2017-01-05    265
#              ...
# 2017-12-27    116
# 2017-12-28    137
# 2017-12-29    124
# 2017-12-30     80
# 2017-12-31     59
# Name: Berri1, Length: 365, dtype: int64

# %% [markdown]
# Ensuite, nous devons ajouter une colonne "jour de la semaine". Tout d'abord, nous pouvons obtenir le jour de la semaine à partir de l'index. Nous n'avons pas encore beaucoup parlé d'index, mais l'index est ce qui se trouve à gauche du cadre de données ci-dessus, sous «Date». Ici, ce sont tous les jours de l'année.

# %%
b=pd.DataFrame(d)

# %%
b
# Out:
#             Berri1
# Date
# 2017-01-01      38
# 2017-01-02     109
# 2017-01-03     141
# 2017-01-04     233
# 2017-01-05     265
# ...            ...
# 2017-12-27     116
# 2017-12-28     137
# 2017-12-29     124
# 2017-12-30      80
# 2017-12-31      59
#
# [365 rows x 1 columns]

# %%
aa=b.index.weekday

# %%
from datetime import datetime
#date=pd.to_datetime(b.index, format = "%d/%m/%Y")

b["jour_dela_semaine"]=aa

# %%
b
# Out:
#             Berri1  jour_dela_semaine
# Date
# 2017-01-01      38                  6
# 2017-01-02     109                  0
# 2017-01-03     141                  1
# 2017-01-04     233                  2
# 2017-01-05     265                  3
# ...            ...                ...
# 2017-12-27     116                  2
# 2017-12-28     137                  3
# 2017-12-29     124                  4
# 2017-12-30      80                  5
# 2017-12-31      59                  6
#
# [365 rows x 2 columns]

# %%
a.index
# Out:
# Index(['01/01/2017', '02/01/2017', '03/01/2017', '04/01/2017', '05/01/2017',
#        '06/01/2017', '07/01/2017', '08/01/2017', '09/01/2017', '10/01/2017',
#        ...
#        '22/12/2017', '23/12/2017', '24/12/2017', '25/12/2017', '26/12/2017',
#        '27/12/2017', '28/12/2017', '29/12/2017', '30/12/2017', '31/12/2017'],
#       dtype='object', name='Date', length=365)

# %% [markdown]
# -2-
#
# Vous pouvez me creer un Dataframe avec ces deux informations  ?

# %% [markdown]
# ### Additionner les cyclistes par jour de la semaine

# %% [markdown]
# -3-
#
# Cela s'avère être vraiment facile!
#
# Les dataframes ont une .groupby()
#
# Je ne vais pas en expliquer plus pour le moment - si vous voulez en savoir plus, la documentation est vraiment bonne.
#
# Dans ce cas, df_precedent.groupby('jour de la semaine').aggregate(sum) signifie "Grouper les lignes par jour de la semaine puis additionner toutes les valeurs du même jour de la semaine".
#
# Allez y !

# %%
#TBD
p=b.groupby('jour_dela_semaine').aggregate(sum)
p
# Out:
#                    Berri1
# jour_dela_semaine
# 0                  122291
# 1                  153303
# 2                  165956
# 3                  157685
# 4                  127579
# 5                  102816
# 6                   94869

# %% [markdown]
# -4-
#
# C'est un peu embetant d'avoir les jours en numéro, changeons ces numéros par leurs noms

# %%
p['j_d_s']=["lundi","mardi","mercredi","jeudi","vendredi","samedi","dimanche"]

#p['index_col'].replace([0,1,2,3,4,5,6],["lundi","mardi","mercredi","jeudi","vendredi","samedi","dimanche"])

# %%
p
# Out:
#                    Berri1     j_d_s
# jour_dela_semaine
# 0                  122291     lundi
# 1                  153303     mardi
# 2                  165956  mercredi
# 3                  157685     jeudi
# 4                  127579  vendredi
# 5                  102816    samedi
# 6                   94869  dimanche

# %% [markdown]
# -5-
#
# Faites moi un petit 'bar' plot() de j_d_s_count  pour bien observer ces tout ça

# %%
import matplotlib.pyplot as plt
p.groupby('j_d_s')['Berri1'].mean().plot(kind='bar');

# %% [markdown]
# On dirait que les habitants de Montréal sont des cyclistes de banlieue - ils font beaucoup plus de vélo pendant la semaine.

# %% [markdown]
# ### Synthese

# %% [markdown]
# -6-
#
# Vous pouvez faire une petite synthese de ce debut de notebook en reprenant les lignes de codes nécessaires à la réalisation de cette visualisation.
#
# Peut être, au lieu de prendre la somme de tous les utilisateurs de chaque jours, prenez le max d'utilisateur par jour

# %%
p.describe()

"""def data_handling(df):
    #TBD
    return bikes_user
    """
# Out:
# 'def data_handling(df):\n    #TBD\n    return bikes_user\n    '

# %% [markdown]
# # Exercices 2

# %% [markdown]
# Ecrire un programme python qui contient  Une Classe climatisation qui a pour fonctionalité :
#
# 1-Allumer si le climatiseur n'est pas allumé, sinon afficher un messager d'erreur le climatiseur est déja allumé.
#
# 2- Eteigner si le climatiseur est  allumé, sinon afficher un messager d'erreur le climatiseur est déja eteigné
#
# Une méthode pour augmenter la températeur ( avec un max 27 degrées), s'il fait déja 27 La climatisation est déjà à sa température maximal
#
# Une méthode pour diminuer la températeur ( avec min 16 degrées), s'il fait déja 16 affiche un message La climatisation est déjà à sa température minimale

# %%
class climatisation:
    
    def __init__(self,a):
        self.a=a
    
   
    
    def allumer(self,a):
        if a==0:
            a=1
        else :
            print('le climatiseur est déjà allumé')
    
    def eteigner(self,a):
        if a==0:
            print('le climatiseur est déja eteigné')
        else :
            a=1
    
    def augmenter(self,a):
        
        if deg<27 :
            deg+=1
        else :
            print(" La climatisation est déjà à sa température maximal")
    
    def diminuer(self,a):
        
        if deg>16:
            deg-=1
        else:
            print(" La climatisation est déjà à sa température minimale")
